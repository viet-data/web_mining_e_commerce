# %% [markdown]
# ##  1. Data Preprocessing <a id="data_preprocessing"></a>

# %% [markdown]
# ### 1.1 Importing Data and Separating Data of Our Interest <a id="1.1"></a>

# %%
import pandas as pd
import numpy as np
import sklearn
from scipy.spatial.distance import cosine

# %%
df = pd.read_csv("test.csv")
df
# Out:
#      Unnamed: 0                                               name  \
# 0           780  giá kẹp điện thoại yunteng xoay 360 độ cho châ...
# 1          5557  sinh trắc vân tay gen talents bài báo cáo đầy ...
# 2          5556  e voucher vietourist tour du lịch miền tây cần...
# 3          5555  gói dịch vụ 1 lần cạo vôi răng và đánh bóng tạ...
# 4          5554  tẩy trắng răng phương pháp laser whitening 5p ...
# ..          ...                                                ...
# 970        4120  khung nắn chỉnh cột sống điều trị thoát vị đĩa...
# 971        4119  thảm tập yoga và gym chất liệu cao cấp tpe 6mm...
# 972        4118  gậy tập thẳng lưng vai gậy chống gù lưng gậy t...
# 973        4117  thảm tập gym thể hình thể dục tại nhà chống tr...
# 974        4116  túi đeo tay đựng điện thoại chạy bộ đai đeo ch...
#
#                                            description
# 0    thông tin nổi bật khung kẹp giữ điện thoại lên...
# 1    nội dung chính của bài báo cáo sinh trắc vân t...
# 2    địa điểm đón kháchđiểm đón 1 5h30 nhà văn hóa ...
# 3    gói dịch vụ 1 lần cạo vôi răng và đánh bóngtại...
# 4    các bước tẩy trắng răng trọn góicombo tẩy trắn...
# ..                                                 ...
# 970  khung nắn chỉnh cột sống điều trị thoát vị đĩa...
# 971  1 thông số kỹ thuật của thảm tập yoga tpe 2 lớ...
# 972  gậy tập thẳng lưng vai chống gù tập yoga gậy c...
# 973  store giao màu thảm là các màu tối 1 mặt quý k...
# 974  túi đeo tay đựng điện thoại chạy bộ đai đeo ch...
#
# [975 rows x 3 columns]

# %%
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#      Unnamed: 0                                               name  \
# 0           780  giá kẹp điện thoại yunteng xoay 360 độ cho châ...
# 1          5557  sinh trắc vân tay gen talents bài báo cáo đầy ...
# 2          5556  e voucher vietourist tour du lịch miền tây cần...
# 3          5555  gói dịch vụ 1 lần cạo vôi răng và đánh bóng tạ...
# 4          5554  tẩy trắng răng phương pháp laser whitening 5p ...
# ..          ...                                                ...
# 970        4120  khung nắn chỉnh cột sống điều trị thoát vị đĩa...
# 971        4119  thảm tập yoga và gym chất liệu cao cấp tpe 6mm...
# 972        4118  gậy tập thẳng lưng vai gậy chống gù lưng gậy t...
# 973        4117  thảm tập gym thể hình thể dục tại nhà chống tr...
# 974        4116  túi đeo tay đựng điện thoại chạy bộ đai đeo ch...
#
#                                            description
# 0    thông tin nổi bật khung kẹp giữ điện thoại lên...
# 1    nội dung chính của bài báo cáo sinh trắc vân t...
# 2    địa điểm đón kháchđiểm đón 1 5h30 nhà văn hóa ...
# 3    gói dịch vụ 1 lần cạo vôi răng và đánh bóngtại...
# 4    các bước tẩy trắng răng trọn góicombo tẩy trắn...
# ..                                                 ...
# 970  khung nắn chỉnh cột sống điều trị thoát vị đĩa...
# 971  1 thông số kỹ thuật của thảm tập yoga tpe 2 lớ...
# 972  gậy tập thẳng lưng vai chống gù tập yoga gậy c...
# 973  store giao màu thảm là các màu tối 1 mặt quý k...
# 974  túi đeo tay đựng điện thoại chạy bộ đai đeo ch...
#
# [975 rows x 3 columns]

# %% [markdown]
# ### 1.2 Creating Preprocessing Function and Applying it on Our Data <a id="1.2"></a>

# %%
with open('vietnamese-stopwords-dash.txt', 'r', encoding='utf-8') as file:
    content = file.readlines()

# Remove leading and trailing whitespaces, and create a list
stop_words = [line.strip() for line in content]

# Print the resulting list
# print(stop_words)

# %%
from string import punctuation
punc = list(punctuation)
stop_words = stop_words + punc

# %%
from pyvi import ViTokenizer

def preprocess(document):
    document = document.lower() # Convert to lowercase
    words = ViTokenizer.tokenize(document) # Tokenize
    words = [w for w in words.split(" ") if not w in stop_words] # Removing stopwords
    # Lemmatizing
    # print(words)
    return " ".join(words)

# %%
preprocess("xịn và rất ấm. Rất phù hợp cho mùa đông")
# Out:
# 'xịn ấm mùa đông'

# %%
df['name'] = df['name'].astype("string")
df['description'] = df['description'].astype("string")

# %%
df = df.dropna(subset=['description'])

# %%
df['description'] = df['name'] + df['description']
df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0         780  giá kẹp điện thoại yunteng xoay 360 độ cho châ...
# 1        5557  sinh trắc vân tay gen talents bài báo cáo đầy ...
# 2        5556  e voucher vietourist tour du lịch miền tây cần...
# 3        5555  gói dịch vụ 1 lần cạo vôi răng và đánh bóng tạ...
# 4        5554  tẩy trắng răng phương pháp laser whitening 5p ...
#
#                                          description
# 0  giá kẹp điện thoại yunteng xoay 360 độ cho châ...
# 1  sinh trắc vân tay gen talents bài báo cáo đầy ...
# 2  e voucher vietourist tour du lịch miền tây cần...
# 3  gói dịch vụ 1 lần cạo vôi răng và đánh bóng tạ...
# 4  tẩy trắng răng phương pháp laser whitening 5p ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# name           string
# description    string
# dtype: object

# %%
df['Processed Review'] = df['description'].apply(preprocess)

df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0         780  giá kẹp điện thoại yunteng xoay 360 độ cho châ...
# 1        5557  sinh trắc vân tay gen talents bài báo cáo đầy ...
# 2        5556  e voucher vietourist tour du lịch miền tây cần...
# 3        5555  gói dịch vụ 1 lần cạo vôi răng và đánh bóng tạ...
# 4        5554  tẩy trắng răng phương pháp laser whitening 5p ...
#
#                                          description  \
# 0  giá kẹp điện thoại yunteng xoay 360 độ cho châ...
# 1  sinh trắc vân tay gen talents bài báo cáo đầy ...
# 2  e voucher vietourist tour du lịch miền tây cần...
# 3  gói dịch vụ 1 lần cạo vôi răng và đánh bóng tạ...
# 4  tẩy trắng răng phương pháp laser whitening 5p ...
#
#                                     Processed Review
# 0  giá kẹp điện_thoại yunteng xoay 360 độ chân tr...
# 1  sinh trắc vân gen talents báo_cáo đầy_đủ 4 mod...
# 2  e voucher vietourist tour du_lịch miền tây cần...
# 3  gói dịch_vụ 1 cạo vôi đánh_bóng nha_khoa thẩm_...
# 4  tẩy trắng phương_pháp laser whitening 5p nha_k...

# %%
df.shape
# Out:
# (975, 4)

# %% [markdown]
# ### 1.3 Creating TF-IDF Matrix <a id="1.3"></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
TF_IDF_matrix = vectorizer.fit_transform(df['Processed Review'])
TF_IDF_matrix = TF_IDF_matrix.T

print('Vocabulary Size : ', len(vectorizer.get_feature_names_out()))
print('Shape of Matrix : ', TF_IDF_matrix.shape)
# Out:
# Vocabulary Size :  6395
# Shape of Matrix :  (6395, 975)

# %%
TF_IDF_matrix_array = TF_IDF_matrix.toarray()

# %%
vectorizer.vocabulary_
# Out:
# {'giá': 2136,
#  'kẹp': 2936,
#  'điện_thoại': 6146,
#  'yunteng': 6050,
#  'xoay': 5961,
#  '360': 420,
#  'độ': 6325,
#  'chân': 1328,
#  'tripod': 5234,
#  'ma_y': 3247,
#  'nh': 3724,
#  'hàng': 2409,
#  'hãngthông': 2501,
#  'nổi_bật': 3951,
#  'khung': 2775,
#  'máy_ảnh': 3457,
#  'hãng': 2429,
#  'sản_xuất': 4715,
#  'chi': 1270,
#  'ha': 2285,
#  'ng': 3607,
#  'máy': 3446,
#  'kích_thước': 2927,
#  '10': 52,
#  '5cm': 562,
#  'gắn': 2256,
#  'sinh': 4554,
#  'trắc': 5318,
#  'vân': 5816,
#  'gen': 2096,
#  'talents': 4794,
#  'báo_cáo': 1041,
#  'đầy_đủ': 6244,
#  'modulenội': 3394,
#  'dung': 1790,
#  'module': 3393,
#  'khám_phá': 2795,
#  'hành': 2417,
#  'viphân': 5755,
#  'tích': 5477,
#  'đặc_tính': 6264,
#  'tiềm_thức': 5143,
#  'thói_quen': 4957,
#  'tư_duy': 5516,
#  'kh': 2755,
#  'voucher': 5790,
#  'vietourist': 5742,
#  'tour': 5182,
#  'du_lịch': 1786,
#  'miền': 3372,
#  'tây': 5472,
#  'cần_thơ': 1628,
#  'sóc': 4679,
#  'trăng': 5285,
#  'bạc': 1085,
#  'liêu': 3068,
#  'đất': 6234,
#  'mũi': 3486,
#  'rừng': 4446,
#  'cà': 1503,
#  'mau': 3276,
#  'đêmđịa': 6183,
#  'đón': 6188,
#  'kháchđiểm': 2792,
#  '5h30': 569,
#  'nhà_văn_hóa': 3762,
#  'thanh_niên': 4844,
#  'phạm': 4123,
#  'ngọc_thạch': 3703,
#  '5h45': 570,
#  'công_ty': 1556,
#  'cổ_phần': 1650,
#  'holdings': 2352,
#  '95b': 717,
#  '97': 720,
#  '99': 723,
#  'trần': 5314,
#  'hưng': 2565,
#  'đạo': 6226,
#  '6h00': 626,
#  'gói': 2238,
#  'dịch_vụ': 1880,
#  'cạo': 1587,
#  'vôi': 5833,
#  'đánh_bóng': 6171,
#  'nha_khoa': 3726,
#  'thẩm_mỹ': 5019,
#  'hồng': 2625,
#  'ângói': 6080,
#  'đánh': 6170,
#  'bóngtại': 1068,
#  'ttct': 5359,
#  'hầu_như': 2596,
#  'sức_khỏe': 4759,
#  'miệng': 3377,
#  'sâu_răng': 4676,
#  'trẻ_em': 5324,
#  'số_liệu': 4738,
#  'chương': 1363,
#  'tẩy': 5554,
#  'trắng': 5319,
#  'phương_pháp': 4117,
#  'laser': 3009,
#  'whitening': 5900,
#  '5p': 583,
#  'bedental': 916,
#  'nhánhcác': 3768,
#  'trọn': 5330,
#  'góicombo': 2241,
#  'răngđể': 4421,
#  'sạch': 4702,
#  'mảng': 3499,
#  'bám': 1033,
#  'thức_ăn': 5072,
#  'nước_bọt': 3911,
#  'tích_tụ': 5481,
#  'khóa': 2809,
#  'học': 2607,
#  'phân_tích': 4092,
#  'dữ_liệu': 1900,
#  'kinh_doanh': 2880,
#  'fundamental': 2060,
#  'business': 1009,
#  'analysis': 812,
#  'tiêu_chuẩn': 5123,
#  'quốc_tế': 4323,
#  'chuyên': 1298,
#  'giabạn': 2117,
#  'lasluzthông': 3011,
#  'chuyên_sâu': 1304,
#  'data': 1706,
#  'căn_bản': 1569,
#  'công_cụ': 1541,
#  'trình_bày': 5267,
#  'thông_qua': 4964,
#  'ngọc': 3702,
#  'huệ': 2393,
#  'spa': 4603,
#  'detox': 1724,
#  'cân': 1520,
#  'spalà': 4606,
#  'phụ_nữ': 4171,
#  'thân_hình': 4941,
#  'thon': 4877,
#  'gọn': 2261,
#  'niềm': 3829,
#  'mơ_ước': 3487,
#  'lý_tưởng': 3141,
#  'giúp': 2154,
#  'tự_tin': 5624,
#  'diện': 1753,
#  'đồ': 6311,
#  'thuận_lợi': 4899,
#  'công_việc': 1562,
#  'dễ_dàng': 1874,
#  'liệu_trình': 3072,
#  'massage': 3271,
#  'thư': 4980,
#  'giãn': 2149,
#  'toàn_thân': 5191,
#  'mệt_mỏi': 3532,
#  '45': 470,
#  'phútliệu': 4111,
#  'trình': 5266,
#  'phút': 4108,
#  'tinh_dầu': 5097,
#  'thiên_nhiên': 4863,
#  'mầm': 3501,
#  'gạo': 2248,
#  'tận_hưởng': 5559,
#  'giây_phút': 2148,
#  'thư_giãn': 4981,
#  'thoải_mái': 4891,
#  'phục_hồi': 4174,
#  'năng_lượng': 3897,
#  'nghỉ_dưỡng': 3629,
#  '2n1đ': 371,
#  'du_thuyền': 1787,
#  'paradise': 4030,
#  'elegance': 1940,
#  'hạng': 2582,
#  'phòng': 4098,
#  'deluxe': 1721,
#  'balconyparadise': 886,
#  'cấu_trúc': 1623,
#  'vỏ': 5872,
#  'thép': 4943,
#  'kết_hợp': 2942,
#  'kiểu_dáng': 2892,
#  'đương_đại': 6212,
#  'phong_cách': 4063,
#  'việt': 5774,
#  'kiệt_tác': 2897,
#  'dòng': 1839,
#  'vịnh': 5871,
#  'hạ': 2578,
#  'long': 3087,
#  'sở_hữu': 4748,
#  'quầy': 4320,
#  'bar': 902,
#  'piano': 4179,
#  'nà': 3855,
#  'tiết_kiệm': 5138,
#  'vé': 5817,
#  'cáp': 1515,
#  'treo': 5229,
#  'xe': 5938,
#  'đưa_đón': 6211,
#  'tận': 5557,
#  'đà_nẵng': 6162,
#  'trưa': 5291,
#  'túclịch': 5503,
#  'tiết07h45': 5136,
#  '08h15': 42,
#  'hướng_dẫn_viên': 2575,
#  'quý_khách': 4302,
#  'khách_sạn': 2789,
#  'hẹn': 2599,
#  'khởi_hành': 2865,
#  'đi': 6128,
#  'tham_quan': 4837,
#  'khu': 2771,
#  'sunworld': 4646,
#  'hills': 2318,
#  '09h00': 45,
#  'khu_vực': 2772,
#  'radisson': 4342,
#  'hotel': 2361,
#  'đối_diện': 6304,
#  'biển': 942,
#  'buffet': 1007,
#  'hồ': 2617,
#  'bơi': 1080,
#  'vô_cực': 5830,
#  'đẹp': 6270,
#  'mớivới': 3553,
#  'tiềm_năng': 5142,
#  'sẵn': 4734,
#  'thời_tiết': 5057,
#  'ôn_hòa': 6090,
#  'nắng': 3933,
#  'ấm': 6374,
#  'rực_rỡ': 4449,
#  'dãy': 1835,
#  'núi': 3880,
#  'hùng_vĩ': 2553,
#  'ôm': 6089,
#  'cung': 1495,
#  'đường': 6214,
#  'nối_liền': 3942,
#  'đất_nước': 6235,
#  'níu': 3870,
#  'combo': 1457,
#  'hôtel': 2552,
#  'colline': 1451,
#  'đà': 6160,
#  'lạt': 3168,
#  'limousine': 3050,
#  'khứ_hồi': 2869,
#  'sài_gòn': 4661,
#  '01': 14,
#  'ngườihôtel': 3691,
#  'nằm': 3936,
#  'quần_thể': 4315,
#  'center': 1252,
#  'chợ': 1403,
#  'đà_lạt': 6161,
#  'lối': 3199,
#  'kiến_trúc': 2886,
#  'độc_đáo': 6331,
#  'lưu_trú': 3148,
#  'đế': 6278,
#  '3n2đ': 444,
#  'intercontinental': 2682,
#  'phú': 4107,
#  'quốc': 4322,
#  'beach': 915,
#  'resort': 4365,
#  'cực': 1681,
#  'miễn_phí': 3376,
#  'tiễn': 5154,
#  'sân_bay': 4674,
#  '02': 27,
#  'người_lớn': 3688,
#  '12': 100,
#  'tuổikhách': 5388,
#  'sạn': 4707,
#  'tọa_lạc': 5589,
#  'bãi': 1045,
#  'trường': 5296,
#  'hoang_sơ': 2349,
#  'phức_hợp': 4178,
#  'phu': 4068,
#  'quoc': 4285,
#  'marina': 3266,
#  'sân': 4673,
#  'evoucher': 1971,
#  'elsa': 1943,
#  'speak': 4609,
#  'english': 1954,
#  'pro': 4232,
#  'phần_mềm': 4132,
#  'tiếng': 5131,
#  'xứlàm': 6027,
#  'lần_lượt': 3170,
#  'quyền_lợi': 4292,
#  'mua': 3425,
#  'tiki': 5089,
#  'chat': 1265,
#  'shop': 4537,
#  'sđt': 4689,
#  '0936368901': 44,
#  'learning': 3027,
#  'speech': 4613,
#  'assistant': 851,
#  'ứng_dụng': 6394,
#  'tân': 5470,
#  'tiến': 5130,
#  'chợ_nổi': 1404,
#  'mỹ': 3561,
#  'tho': 4875,
#  'bến': 1141,
#  'tre': 5225,
#  'thơlịch': 4975,
#  'tuầnngày': 5379,
#  'thơ': 4973,
#  'tối': 5591,
#  '7h30': 654,
#  'đội_ngũ': 6332,
#  'nhân_viên': 3776,
#  'tài_xế': 5448,
#  'đón_tiếp': 6189,
#  'văn_phòng': 5842,
#  'sài': 4660,
#  'gòn': 2235,
#  'tiên_phong': 5118,
#  '171': 189,
#  'pha': 4044,
#  'ngu': 3646,
#  'lão': 3130,
#  'khánh': 2797,
#  'hương': 2566,
#  'xông_hơi': 6004,
#  'body': 983,
#  'foot': 2024,
#  'béo': 1051,
#  'đắp': 6255,
#  'mặt': 3518,
#  'nạsau': 3926,
#  'làm_việc': 3112,
#  'căng_thẳng': 1572,
#  'đàn_ông': 6168,
#  'nghỉ_ngơi': 3630,
#  'gia_đình': 2115,
#  'tất_bật': 5549,
#  'nấu': 3929,
#  'cơm': 1580,
#  'lau': 3015,
#  'giặt_giũ': 2181,
#  'dọn_dẹp': 1884,
#  'cường_độ': 1584,
#  'victoria': 5737,
#  'phan_thiết': 4049,
#  'trung_tâm': 5243,
#  'névictoria': 3868,
#  'vô_cùng': 5829,
#  'gần_gũi': 2251,
#  'nét': 3867,
#  'hiện_đại': 2330,
#  'đậm_nét': 6248,
#  'nam': 3566,
#  'truyền_thống': 5251,
#  'kì': 2921,
#  'nghỉ': 3628,
#  'th': 4830,
#  'tràm': 5255,
#  '2n1d': 370,
#  'melia': 3295,
#  'ngườiso': 3692,
#  'vũng_tàu': 5846,
#  'thành_phố': 4915,
#  'chật_ních': 1378,
#  'mùa': 3482,
#  'bình_yên': 1061,
#  'hiếm': 2320,
#  'giản_đơn': 2168,
#  'bả': 1098,
#  'tâm': 5463,
#  'tiêu': 5121,
#  'chuẩn1': 1314,
#  'ngành': 3662,
#  'khoa_học': 2764,
#  'nghiên_cứu': 3620,
#  'liên_hệ': 3064,
#  'ngón': 3675,
#  'não': 3864,
#  'hạn_chế': 2581,
#  'bẩm_sinh': 1124,
#  'tuyệt_đỉnh': 5373,
#  'microsoft': 3320,
#  'word': 5915,
#  'chuyên_gia': 1302,
#  'soạn_thảo': 4601,
#  'văn': 5839,
#  'bảnmô': 1108,
#  'tả': 5539,
#  'khoá': 2767,
#  'họcmicrosoft': 2613,
#  'văn_bản': 5840,
#  'hiệu_quả': 2336,
#  'tận_dụng': 5558,
#  'hcm': 2296,
#  'hàn': 2405,
#  '4n4đ': 507,
#  'visa': 5757,
#  'ks': 2904,
#  'bay': 909,
#  'vietjet': 5740,
#  'air': 786,
#  'lễ': 3183,
#  'noel': 3832,
#  'tết': 5581,
#  'dương_lịch': 1853,
#  'âm': 6075,
#  'lịchngày': 3193,
#  'tp': 5195,
#  'seoul': 4514,
#  'đêm': 6181,
#  'máy_bay': 3447,
#  'nhẹ': 3811,
#  'tân_sơn': 5471,
#  'ga': 2071,
#  'trưởng_đoàn_phát': 5303,
#  'hướng_dẫn': 2574,
#  'thủ_tục': 5068,
#  'key': 2746,
#  'diệt': 1757,
#  'virus': 5756,
#  'kaspersky': 2733,
#  'standard': 4622,
#  'hãngbảo': 2435,
#  'mật_thiết_yếu': 3509,
#  'phòng_chống': 4099,
#  'malware': 3263,
#  'lây_nhiễm': 3126,
#  'tập_tin': 5565,
#  'website': 5893,
#  'ransomware': 4345,
#  'ngăn_chặn': 3681,
#  'tấn_công': 5547,
#  'mạng': 3494,
#  'máy_tính': 3454,
#  'tường': 5531,
#  'lửa': 3223,
#  'giám_sát': 2140,
#  'luồng': 3101,
#  'truy_cập': 5246,
#  'chống': 1397,
#  'kỹ_năng': 2956,
#  'tranh_luận': 5216,
#  'thuyết_phục': 4896,
#  'thinking': 4859,
#  'school': 4495,
#  'onlinekhóa': 3979,
#  'thảo_luận': 5007,
#  'tổ_chức': 5601,
#  'chủ_đề': 1409,
#  'online': 3976,
#  'tương_tác': 5529,
#  'revit': 4369,
#  'mep': 3300,
#  'cb': 1247,
#  'nc': 3597,
#  'giảng_viên': 2171,
#  'zoomchuẩn': 6066,
#  'đầu_ra': 6238,
#  'hoàn_thành': 2370,
#  'vẽ': 5862,
#  'khái_niệm': 2794,
#  'bim': 932,
#  'áp_dụng': 6072,
#  'thiết_kế': 4869,
#  'thi': 4855,
#  'côn': 1538,
#  'telesale': 4821,
#  'nghiệptổng': 3623,
#  'quanbạn': 4272,
#  'telesales': 4822,
#  'thường_xuyên': 4993,
#  'kết_thúc': 2946,
#  'cuộc_gọi': 1499,
#  'khó_chịu': 2808,
#  'khách_hàng': 2788,
#  'kịch_bản': 2949,
#  'gọi': 2260,
#  'premium': 4231,
#  'thiết_bị': 4868,
#  'hãngtương': 2508,
#  'windows': 5907,
#  'macos': 3250,
#  'android': 817,
#  'iosbảo': 2691,
#  'qr': 4265,
#  'code': 1446,
#  'show': 4539,
#  'ký_ức': 2931,
#  'hội': 2631,
#  'an': 808,
#  'ghế': 2109,
#  'eco': 1913,
#  'tặng': 5577,
#  'thuyền_thúng': 4897,
#  'dừa': 1898,
#  'bảy': 1118,
#  'mẫuvé': 3506,
#  'diễn': 1752,
#  'econếu': 1918,
#  'trót': 5280,
#  'yêu': 6057,
#  'ngõ': 3678,
#  'ngoằn_ngoèo': 3645,
#  'nối_đuôi': 3943,
#  'bất_tận': 1121,
#  'chiều': 1285,
#  'sâu': 4675,
#  'văn_hóa': 5841,
#  'vùng_đất': 5837,
#  'cổ': 1649,
#  'chương_trình': 1364,
#  'biểu': 943,
#  'diễ': 1751,
#  'bảo_hiểm': 1111,
#  'tnds': 5170,
#  'ô_tô': 6088,
#  'chỗ': 1399,
#  'giấy': 2174,
#  'chứng_nhận': 1419,
#  'điện_tử': 6150,
#  'quân_đội': 4298,
#  'micbảo': 3315,
#  'hiểm_tnds': 2322,
#  'bắt_buộc': 1137,
#  '24': 307,
#  'tải': 5541,
#  'mic': 3314,
#  'đối_tượng': 6307,
#  'chủ': 1406,
#  'cơ_giới': 1576,
#  'tham_gia': 4834,
#  'giao_thông': 2124,
#  'lãnh_thổ': 3128,
#  'cộn': 1657,
#  'bình': 1057,
#  '2n2đ': 372,
#  'lặn': 3182,
#  'ngắm': 3699,
#  'san_hô': 4486,
#  'bbq': 913,
#  'hải_sản': 2588,
#  'nồm': 3946,
#  'chùa': 1354,
#  'ốc': 6381,
#  'vườn': 5849,
#  'nho': 3752,
#  'giường_nằm': 2158,
#  'tuần': 5376,
#  'dịp': 1881,
#  'tếtđêm': 5582,
#  'cam': 1208,
#  'ranh': 4344,
#  'địa_điểm': 6290,
#  'big': 931,
#  'trường_chinh': 5297,
#  '20h15': 277,
#  '30k': 381,
#  'giày': 2134,
#  'sửa_chữa': 4763,
#  'bảo_vệ': 1117,
#  'hóa': 2545,
#  'đơn': 6205,
#  '149k': 148,
#  'extrimáp_dụng': 1982,
#  'bao_gồm': 899,
#  'phí': 4095,
#  'ship': 4533,
#  'màu': 3435,
#  'thân': 4940,
#  'nhuộm': 3757,
#  'dán': 1818,
#  'khâu': 2800,
#  'may': 3286,
#  'fit': 2014,
#  'master': 3273,
#  'tập': 5561,
#  'gym': 2225,
#  'groupx': 2217,
#  'yoga': 6041,
#  'giới_hạn': 2188,
#  'session': 4519,
#  'pt': 4236,
#  'inbodyđến': 2668,
#  'fitness': 2015,
#  'hình_thể': 2527,
#  'săn': 4687,
#  'dẻo_dai': 1872,
#  'hoàn_hảo': 2368,
#  'trở_ngại': 5349,
#  'hướng': 2572,
#  'trải': 5311,
#  'nghiệm': 3622,
#  'analyzer': 813,
#  'thángbạn': 4926,
#  'cảm_thấytự': 1595,
#  'ti': 5083,
#  'hồi_hộp': 2619,
#  'xấu_hổ': 6016,
#  'giao_tiếp': 2125,
#  'bận_rộn': 1127,
#  'cam_kết': 1209,
#  'cố_định': 1644,
#  'xu_hướng': 5969,
#  'toàn': 5185,
#  'bảo_hiểm_bình': 1112,
#  '365': 423,
#  'tai_nạn': 4790,
#  '247': 311,
#  'pvi': 4244,
#  'quốcviệt': 4331,
#  'đứng': 6349,
#  'đầu': 6237,
#  'đông': 6197,
#  'tỉ_lệ': 5585,
#  'thiệt_mạng': 4873,
#  '970': 721,
#  '2018': 248,
#  'rủi_ro': 4445,
#  'xảy': 6015,
#  'phương_tiện': 4119,
#  'xe_máy': 5940,
#  'phổ_biến': 4167,
#  'diệp': 1756,
#  'mẹ': 3523,
#  'hải': 2587,
#  '1n1đ': 229,
#  'nhà_thờ': 3760,
#  'tắc': 5569,
#  'sậy': 4720,
#  'công_tử': 1560,
#  'cánh': 1511,
#  'đồng': 6318,
#  'điện': 6142,
#  'gió': 2150,
#  'thiền': 4871,
#  'viện': 5773,
#  'trúc': 5283,
#  'lâm': 3120,
#  'som': 4589,
#  'rong': 4395,
#  'tượng': 5533,
#  'phật': 4162,
#  'ca': 1197,
#  'namđêm': 3579,
#  'chí': 1346,
#  'minh': 3334,
#  'liêu20h30': 3069,
#  'hdv': 2309,
#  'top': 5176,
#  'travels': 5224,
#  '20h30': 279,
#  'thạnh': 5001,
#  '20h50': 280,
#  'đình': 6185,
#  'ông_bà': 6091,
#  'blu': 971,
#  'tuổitận': 5396,
#  'hưởng': 2576,
#  'làn': 3114,
#  'thổi': 5052,
#  'tế_bào': 5580,
#  'cuộc_sống': 1500,
#  'hồi_sinh': 2622,
#  'tươi': 5520,
#  'từ_chối': 5613,
#  'kỳ': 2952,
#  'vùng_biển': 5836,
#  'đảo': 6231,
#  'le': 3024,
#  'viva': 5762,
#  'né': 3865,
#  'huỳnh': 2394,
#  'thúc': 4970,
#  'kháng': 2796,
#  'thuận_tiện': 4900,
#  'tham': 4833,
#  'quanmũi': 4275,
#  'cảnh': 1600,
#  'hiền': 2321,
#  'hòa': 2535,
#  'thơ_mộng': 4974,
#  'ao_ước': 829,
#  'đặt_chân': 6266,
#  'ghé': 2106,
#  'nỗi': 3955,
#  'lưu_luyến': 3147,
#  'mong': 3397,
#  'trở_lại': 5348,
#  'nhữ': 3820,
#  'vietravel': 5743,
#  'trung': 5240,
#  'trương': 5292,
#  'gia': 2113,
#  'giới': 2187,
#  'phượng_hoàng': 4120,
#  'trấn': 5312,
#  'thiên_môn': 4862,
#  'sơn_viên': 4693,
#  'giớingày': 2190,
#  'giớitrưởng': 2191,
#  'đoàn': 6155,
#  'đáp': 6174,
#  'chuyến': 1308,
#  'thẳng': 5029,
#  'hành_trình': 2420,
#  'quá_cảnh': 4294,
#  'centara': 1251,
#  'mirage': 3351,
#  'vui_chơi': 5798,
#  'công_viên': 1561,
#  'nướccentara': 3917,
#  'xây': 5993,
#  'tiện_ích': 5159,
#  'giải_trí': 2164,
#  'địa': 6286,
#  'hotels': 2362,
#  'resorts': 4366,
#  'tập_đoàn': 5567,
#  'quản_lý': 4307,
#  'nổi_tiếng': 3952,
#  'monkey': 3399,
#  'junior': 2724,
#  'trẻ': 5323,
#  'đời': 6342,
#  'nămchương': 3887,
#  '000': 1,
#  'cụm': 1665,
#  'câu': 1524,
#  'đơn_giản': 6207,
#  'nâng': 3857,
#  'kho': 2762,
#  'hình_ảnh': 2530,
#  'video': 5738,
#  'sinh_động': 4560,
#  'âm_thanh': 6078,
#  'giọng': 2183,
#  'đọc': 6298,
#  'chuẩn': 1313,
#  'bản_xứ': 1102,
#  '21': 288,
#  'bắc': 1134,
#  '4n3d': 506,
#  'nội': 3956,
#  'hà': 2396,
#  'ninh': 3826,
#  'sapa': 4490,
#  'fansipan': 1994,
#  'hằng': 2597,
#  'ngàydu': 3664,
#  'lịch': 3190,
#  'namtour': 3578,
#  'hà_nội': 2399,
#  'bái': 1032,
#  'đính': 6186,
#  'tràng': 5257,
#  'bàithời': 1019,
#  'gian': 2119,
#  'đêmkhởi': 6182,
#  'mã': 3462,
#  'lt2ngày': 3093,
#  'quý': 4301,
#  'stories': 4631,
#  'anhmonkey': 820,
#  'phát_triển': 4081,
#  'ngôn_ngữ': 3677,
#  'hàng_đầu': 2412,
#  'thư_viện': 4983,
#  'truyện': 5253,
#  'mới_lạ': 3544,
#  'đồ_sộ': 6315,
#  'hệ_thống': 2604,
#  'bài_học': 1017,
#  'đư': 6210,
#  'chay': 1266,
#  '60': 597,
#  'món': 3473,
#  'vu': 5795,
#  'lan': 2987,
#  '2022': 259,
#  'capella': 1236,
#  'parkviewtái': 4033,
#  'khơi': 2822,
#  'tâm_thức': 5469,
#  'ănn': 6098,
#  'phương_cách': 4116,
#  'thanh_lọc': 4843,
#  'cơ_thể': 1578,
#  'cân_bằng': 1521,
#  'an_lạc': 809,
#  'tâm_hồn': 5466,
#  'ước_vọng': 6369,
#  'đem': 6115,
#  'mệnh_giá': 3531,
#  '000vnd': 5,
#  'thái': 4922,
#  '990': 724,
#  '0000mệnh': 2,
#  '000đ': 6,
#  'trở': 5346,
#  'thanh_toán': 4846,
#  'chênh_lệch': 1341,
#  'ví_dụ': 5822,
#  '000vn': 4,
#  'swandor': 4656,
#  'bữa': 1184,
#  'mini': 3345,
#  'kháchswandor': 2791,
#  'dọc': 1883,
#  'xinh_đẹp': 5952,
#  'trong_vắt': 5238,
#  'cung_cấp': 1496,
#  'trang_nhã': 5206,
#  'bờ': 1180,
#  'ngoài_trời': 3635,
#  'đệ': 6282,
#  'tứ': 5611,
#  'united': 5670,
#  'kích_cầu': 2924,
#  'du': 1784,
#  'châu_đốc': 1334,
#  'sam': 4476,
#  'cấm': 1603,
#  'lăng': 3143,
#  'thoại': 4885,
#  'hầu': 2595,
#  'hang': 2289,
#  'cửa_khẩu': 1679,
#  'tịnh': 5588,
#  'biênđêm': 935,
#  'châu': 1333,
#  'đốc20h00': 6302,
#  '20h00': 276,
#  '20h20': 278,
#  'olive': 3971,
#  'trẻ_hóa': 5325,
#  'nhăn': 3784,
#  'da': 1691,
#  'chăm_sóc': 1359,
#  'spathư': 4608,
#  'massagetrong': 3272,
#  'con_người': 1465,
#  'áp_lực': 6073,
#  'rơi': 4424,
#  'stress': 4634,
#  'ảnh_hưởng': 6372,
#  'nghiêm_trọng': 3618,
#  '5n4đ': 582,
#  'baiyoke': 884,
#  'sky': 4569,
#  'sa0': 4469,
#  'cổ_truyền': 1652,
#  'tháingày': 4924,
#  'bangkok': 893,
#  'trưởng_đoàn': 5302,
#  'checkin': 1268,
#  'dùng_bữa': 1843,
#  'merperle': 3301,
#  'hòn': 2543,
#  'tằm': 5576,
#  'sparkling': 4607,
#  'waves': 5886,
#  'tắm': 5571,
#  'bùn': 1073,
#  'kháchkhu': 2790,
#  'cao_cấp': 1223,
#  'địa_thế': 6289,
#  'nha': 3725,
#  'trang': 5204,
#  'cano': 1217,
#  'cao_tốc': 1230,
#  'tếtọa': 5583,
#  'lạc': 3158,
#  'vàng': 5807,
#  'tầm': 5550,
#  'bao_quát': 900,
#  'toàn_bộ': 5186,
#  'hình': 2525,
#  'dhawa': 1732,
#  'ngườidhawa': 3690,
#  'ưu_đãi': 6367,
#  'hè': 2521,
#  '2023': 266,
#  'tổ_hợp': 5602,
#  'angsana': 819,
#  'banyan': 895,
#  'tree': 5226,
#  'group': 2216,
#  'cổng': 1654,
#  'tiniworld': 5105,
#  'có_giá': 1528,
#  '150': 156,
#  'vnđhướng': 5786,
#  'thành_công': 4911,
#  'ecode': 1916,
#  'gửi': 2276,
#  'nhập': 3804,
#  'vui_lòng': 5799,
#  'xuất_trình': 5978,
#  'nhận_diện': 3803,
#  'kiểm': 2887,
#  'tmv': 5169,
#  'điều_trị': 6138,
#  'thâm_quầng': 4939,
#  'mắt': 3511,
#  'sống': 4743,
#  'cửa_sổ': 1680,
#  'hồnđiều': 2627,
#  'trị': 5328,
#  'thẩm_mỹ_viện': 5020,
#  'đánh_bại': 6172,
#  'quầng': 4319,
#  'thâm': 4938,
#  'giành': 2131,
#  'sức_sống': 4761,
#  'đôi': 6195,
#  'mắtthâm': 3514,
#  'hiện_tượng': 2328,
#  'sắc_tố': 4726,
#  'sạm': 4705,
#  'công_nghệ': 1545,
#  'nhật': 3807,
#  '70': 637,
#  'kết': 2940,
#  'họp': 2615,
#  'ngâm': 3673,
#  'paraffin': 4031,
#  'miễn': 3375,
#  'tipcuộc': 5106,
#  'nhu_cầu': 3755,
#  'sắc_đẹp': 4727,
#  'tu': 5360,
#  'bẹn': 1140,
#  'siêu': 4564,
#  'ipac': 2700,
#  'laserđiều': 3010,
#  'dungipac': 1796,
#  'giải_pháp': 2161,
#  'đột_phá': 6341,
#  'cứu_cánh': 1672,
#  'sạmlaser': 4706,
#  'công_nghệ_cao': 1546,
#  'siêu_âm': 4565,
#  'hânnha': 2428,
#  'khoa': 2763,
#  'hân': 2427,
#  'hoạt_động': 2380,
#  'sứ_mệnh': 4755,
#  'chất_lượng': 1373,
#  'góp_phần': 2243,
#  'công_tác': 1558,
#  'cộng_đồng': 1659,
#  'phương_châm': 4115,
#  'lợi_ích': 3213,
#  'năm_ứng_dụng': 3884,
#  'sách': 4665,
#  'umbalenavới': 5663,
#  'xây_dựng': 5994,
#  'thế_hệ': 5036,
#  'ham': 2287,
#  'umbalena': 5662,
#  'trực_tuyến': 5356,
#  'khổng_lồ': 2863,
#  'đầu_tư': 6239,
#  'bài_bản': 1016,
#  'đam_mê': 6107,
#  'tâm_huyết': 5464,
#  'phát': 4077,
#  'tri': 5232,
#  'swiss': 4658,
#  'bel': 920,
#  'tuyền': 5368,
#  'view': 5745,
#  'nhà_xe': 3763,
#  'hấp': 2590,
#  'dẫnswiss': 1869,
#  'belresort': 922,
#  'tuyệt': 5370,
#  'lâmđược': 3122,
#  'bao': 896,
#  'quanh': 4274,
#  'đồi': 6317,
#  'cảnh_quan': 1601,
#  ...}

# %% [markdown]
# ## 2. Apply SVD to TF-IDF Matrix <a id="apply_svd"></a>

# %%
from scipy.sparse.linalg import svds

num_components = 256
U, s, VT = svds(TF_IDF_matrix_array, k=num_components)

TF_IDF_matrix_reduced = np.dot(U, np.dot(np.diag(s), VT))

# Getting document and term representation
terms_rep = np.dot(U, np.diag(s)) # M X K matrix where M = Vocabulary Size and N = Number of documents
docs_rep = np.dot(np.diag(s), VT).T # N x K matrix

# %%
TF_IDF_matrix_reduced.shape
# Out:
# (6395, 975)

# %%
# This is a function to generate query_rep

def lsa_query_rep(query):
    query_rep = [vectorizer.vocabulary_[x] if x in vectorizer.vocabulary_.keys() else 0 for x in preprocess(query).split()]
    query_rep = np.mean(terms_rep[query_rep],axis=0)
    return query_rep

# %%
def retrieve_tfidf(query):

    query_rep = lsa_query_rep(query)

    query_doc_cos_dist = [cosine(query_rep, doc_rep) for doc_rep in docs_rep]
    query_doc_sort_index = np.argsort(np.array(query_doc_cos_dist))
    
    return query_doc_sort_index, np.sort(np.array([1-i for i in query_doc_cos_dist]))[::-1]

query_index, query_score = retrieve_tfidf("Tìm kiếm về các mẫu máy giặt tiết kiệm điện mới nhất trên thị trường")

print(query_index[0:3], df['description'][query_index[:3]].to_list())
query_score[0:3]

#     for rank, sort_index in enumerate(query_doc_sort_index[:3]):
#         print ('Rank : ', rank + 1, ' Consine : ', 1 - query_doc_cos_dist[sort_index],'\n','Product Name: ', df['product_name'][sort_index],'\n','Description: ', df['short_description'][sort_index])
# Out:
# [280 322 181] ['dây curoa máy giặt m18 m18 5 m19 m19 5 m20 m20 5 m21 m21 5dây curoa máy giặt m18 m18 5 m19 m19 5 m20 m20 5 m21 m21 5với loại máy giặt dùng dây curoa hay còn gọi là vành đai máy giặt để giúp máy giặt chuyển động qua thời gian sử dụng máy giặt lâu ngày', 'bộ 4 chân đế chống rung chân đỡ đa năng chống rung lắc máy giặt đời mớivới bộ 4 đệm cao su tính năng chống trượt chống di chuyển sẽ giữ cho máy giặt ở yên tại chỗ giảm tiếng ồn khi giặt phù hợp với hầu hết các thương hiệu máy giặt phù hợp máy giặt', 'phao áp lực máy giặt cho electrolux hàng hãng 19502 van áp lực máy giặt electrolux hàng hãng 19502 phao máy giặt electrolux hàng hãngphao áp lực máy giặt elec hàng hãng 19502phao áp suất hay còn gọi là van áp lực máy giặt thực chất là một công tắc cảm biến mức nước được kết nối trực tiếp với board mạch vai trò chính là xác định m']
# array([0.60202835, 0.59110665, 0.56980715])

# %%
df['description'][309]
# Out:
# 'nhập 1212b65k giảm 65k đơn 999k máy giặt toshiba inverter 8 5 kg tw bk95s3v sk model 2021 hàng chính hãng chỉ giao hcmgiao hàng và lắp đặt cùng lúc khu vực cần giờ có giao hàng tính phí vui lòng liên hệ trước lắp đặt miễn phí lúc giao hàng ở nhà trệt có thang máy vật tư phát sinh tính phí cần hỗ trợ giao hàn'

# %%
df_test = pd.read_csv("testdataset.csv", index_col = 0)
df_test.head()
# Out:
#                                             question       product_id
# 0  Tìm kiếm về các mẫu máy giặt tiết kiệm điện mớ...  [250, 355, 309]
# 1  Các thương hiệu nào sản xuất máy giặt tiết kiệ...  [250, 355, 309]
# 2  Tìm hiểu về chương trình khuyến mãi máy giặt t...  [250, 355, 309]
# 3  Tìm kiếm về máy giặt tiết kiệm điện với công n...  [250, 355, 309]
# 4  Các mẫu máy giặt tiết kiệm điện phù hợp cho gi...  [250, 355, 309]

# %%
df_test.shape
# Out:
# (360, 2)

# %%
from tqdm import tqdm

test_result = []

for query in tqdm(df_test["question"].values, desc="Processing queries"):
    query_index, query_score = retrieve_tfidf(query)
    answer = {}
    answer["query"] = query
    answer["index"] = query_index
    answer["top5_product"] = df.loc[query_index[:5], 'name'].tolist()
    answer["top5_description"] = df.loc[query_index[:5], 'description'].tolist()
    answer["score"] = query_score
    test_result.append(answer)
# Out:
# Processing queries:   1%|          | 2/360 [00:00<00:37,  9.62it/s]
# Processing queries: 100%|██████████| 360/360 [00:16<00:00, 22.48it/s]

# %%
pred_all = [list(i["index"]) for i in test_result]

# %%
pred = [list(i["index"]) for i in test_result]

# %%
import ast
test_Y = [ast.literal_eval(i) for i in (list(df_test["product_id"]))]
test_Y[0]
# Out:
# [250, 355, 309]

# %%
def calculate_map(test_Y, pred):

    Q = len(test_Y)
    ap = []

    # loop through and calculate AP for each query q
    for q in range(Q):
        ap_num = 0
        # loop through k values
        for x in range(len(pred[q])):
            # calculate precision@k
            act_set = set(test_Y[q])                                                                                                                                   
            pred_set = set(pred[q][:x+1])
            precision_at_k = len(act_set & pred_set) / (x+1)
            # calculate rel_k values
            if pred[q][x] in test_Y[q]:
                rel_k = 1
            else:
                rel_k = 0
            # calculate numerator value for ap
            ap_num += precision_at_k * rel_k
        # now we calculate the AP value as the average of AP
        # numerator values
        ap_q = ap_num / len(test_Y[q])
        print(f"AP@{len(pred[q])}_{q+1} = {round(ap_q,2)}")
        ap.append(ap_q)

    # now we take the mean of all ap values to get mAP
    map_at_k = sum(ap) / Q

    # generate results
    print(f"mAP@{len(pred[q])} = {round(map_at_k, 4)}")

    return map_at_k

calculate_map(test_Y, pred)
# Out:
# AP@975_1 = 0.11
# AP@975_2 = 0.08
# AP@975_3 = 0.09
# AP@975_4 = 0.13
# AP@975_5 = 0.11
# AP@975_6 = 0.27
# AP@975_7 = 0.12
# AP@975_8 = 0.2
# AP@975_9 = 0.26
# AP@975_10 = 0.12
# AP@975_11 = 0.05
# AP@975_12 = 0.19
# AP@975_13 = 0.25
# AP@975_14 = 0.07
# AP@975_15 = 0.04
# AP@975_16 = 0.22
# AP@975_17 = 0.12
# AP@975_18 = 0.12
# AP@975_19 = 0.09
# AP@975_20 = 0.12
# AP@975_21 = 0.42
# AP@975_22 = 0.31
# AP@975_23 = 0.42
# AP@975_24 = 0.01
# AP@975_25 = 0.05
# AP@975_26 = 0.43
# AP@975_27 = 0.38
# AP@975_28 = 0.42
# AP@975_29 = 0.31
# AP@975_30 = 0.01
# AP@975_31 = 0.08
# AP@975_32 = 0.06
# AP@975_33 = 0.08
# AP@975_34 = 0.05
# AP@975_35 = 0.08
# AP@975_36 = 0.06
# AP@975_37 = 0.01
# AP@975_38 = 0.08
# AP@975_39 = 0.06
# AP@975_40 = 0.01
# AP@975_41 = 0.01
# AP@975_42 = 0.01
# AP@975_43 = 0.03
# AP@975_44 = 0.02
# AP@975_45 = 0.01
# AP@975_46 = 0.01
# AP@975_47 = 0.01
# AP@975_48 = 0.02
# AP@975_49 = 0.01
# AP@975_50 = 0.01
# AP@975_51 = 0.02
# AP@975_52 = 0.02
# AP@975_53 = 0.02
# AP@975_54 = 0.0
# AP@975_55 = 0.02
# AP@975_56 = 0.02
# AP@975_57 = 0.02
# AP@975_58 = 0.03
# AP@975_59 = 0.01
# AP@975_60 = 0.01
# AP@975_61 = 0.05
# AP@975_62 = 0.26
# AP@975_63 = 0.01
# AP@975_64 = 0.05
# AP@975_65 = 0.01
# AP@975_66 = 0.06
# AP@975_67 = 0.01
# AP@975_68 = 0.02
# AP@975_69 = 0.06
# AP@975_70 = 0.01
# AP@975_71 = 0.02
# AP@975_72 = 0.02
# AP@975_73 = 0.02
# AP@975_74 = 0.02
# AP@975_75 = 0.02
# AP@975_76 = 0.02
# AP@975_77 = 0.02
# AP@975_78 = 0.02
# AP@975_79 = 0.01
# AP@975_80 = 0.02
# AP@975_81 = 0.01
# AP@975_82 = 0.01
# AP@975_83 = 0.0
# AP@975_84 = 0.0
# AP@975_85 = 0.02
# AP@975_86 = 0.01
# AP@975_87 = 0.02
# AP@975_88 = 0.03
# AP@975_89 = 0.07
# AP@975_90 = 0.02
# AP@975_91 = 0.02
# AP@975_92 = 0.05
# AP@975_93 = 0.04
# AP@975_94 = 0.03
# AP@975_95 = 0.05
# AP@975_96 = 0.04
# AP@975_97 = 0.01
# AP@975_98 = 0.02
# AP@975_99 = 0.03
# AP@975_100 = 0.02
# AP@975_101 = 0.0
# AP@975_102 = 0.01
# AP@975_103 = 0.01
# AP@975_104 = 0.0
# AP@975_105 = 0.02
# AP@975_106 = 0.01
# AP@975_107 = 0.0
# AP@975_108 = 0.01
# AP@975_109 = 0.0
# AP@975_110 = 0.0
# AP@975_111 = 0.77
# AP@975_112 = 0.85
# AP@975_113 = 0.77
# AP@975_114 = 0.85
# AP@975_115 = 0.77
# AP@975_116 = 0.85
# AP@975_117 = 0.77
# AP@975_118 = 0.85
# AP@975_119 = 0.85
# AP@975_120 = 0.85
# AP@975_121 = 0.83
# AP@975_122 = 0.92
# AP@975_123 = 0.92
# AP@975_124 = 0.89
# AP@975_125 = 0.85
# AP@975_126 = 0.81
# AP@975_127 = 0.88
# AP@975_128 = 0.83
# AP@975_129 = 0.82
# AP@975_130 = 0.89
# AP@975_131 = 0.19
# AP@975_132 = 0.25
# AP@975_133 = 0.16
# AP@975_134 = 0.24
# AP@975_135 = 0.15
# AP@975_136 = 0.18
# AP@975_137 = 0.23
# AP@975_138 = 0.15
# AP@975_139 = 0.25
# AP@975_140 = 0.16
# AP@975_141 = 0.21
# AP@975_142 = 0.21
# AP@975_143 = 0.21
# AP@975_144 = 0.09
# AP@975_145 = 0.22
# AP@975_146 = 0.17
# AP@975_147 = 0.19
# AP@975_148 = 0.21
# AP@975_149 = 0.2
# AP@975_150 = 0.18
# AP@975_151 = 0.01
# AP@975_152 = 0.01
# AP@975_153 = 0.01
# AP@975_154 = 0.03
# AP@975_155 = 0.01
# AP@975_156 = 0.01
# AP@975_157 = 0.04
# AP@975_158 = 0.01
# AP@975_159 = 0.01
# AP@975_160 = 0.01
# AP@975_161 = 0.17
# AP@975_162 = 0.18
# AP@975_163 = 0.17
# AP@975_164 = 0.17
# AP@975_165 = 0.17
# AP@975_166 = 0.17
# AP@975_167 = 0.18
# AP@975_168 = 0.17
# AP@975_169 = 0.17
# AP@975_170 = 0.02
# AP@975_171 = 0.03
# AP@975_172 = 0.01
# AP@975_173 = 0.04
# AP@975_174 = 0.1
# AP@975_175 = 0.05
# AP@975_176 = 0.03
# AP@975_177 = 0.01
# AP@975_178 = 0.01
# AP@975_179 = 0.04
# AP@975_180 = 0.03
# AP@975_181 = 0.67
# AP@975_182 = 0.08
# AP@975_183 = 0.7
# AP@975_184 = 0.58
# AP@975_185 = 0.69
# AP@975_186 = 0.66
# AP@975_187 = 0.46
# AP@975_188 = 0.6
# AP@975_189 = 0.7
# AP@975_190 = 0.64
# AP@975_191 = 0.04
# AP@975_192 = 0.05
# AP@975_193 = 0.05
# AP@975_194 = 0.03
# AP@975_195 = 0.05
# AP@975_196 = 0.04
# AP@975_197 = 0.04
# AP@975_198 = 0.05
# AP@975_199 = 0.02
# AP@975_200 = 0.05
# AP@975_201 = 0.05
# AP@975_202 = 0.08
# AP@975_203 = 0.08
# AP@975_204 = 0.14
# AP@975_205 = 0.13
# AP@975_206 = 0.13
# AP@975_207 = 0.14
# AP@975_208 = 0.08
# AP@975_209 = 0.12
# AP@975_210 = 0.06
# AP@975_211 = 0.79
# AP@975_212 = 0.75
# AP@975_213 = 0.87
# AP@975_214 = 0.93
# AP@975_215 = 0.74
# AP@975_216 = 0.75
# AP@975_217 = 0.87
# AP@975_218 = 0.75
# AP@975_219 = 0.93
# AP@975_220 = 0.75
# AP@975_221 = 0.81
# AP@975_222 = 0.0
# AP@975_223 = 0.07
# AP@975_224 = 0.01
# AP@975_225 = 0.81
# AP@975_226 = 0.01
# AP@975_227 = 0.63
# AP@975_228 = 0.01
# AP@975_229 = 0.81
# AP@975_230 = 0.01
# AP@975_231 = 0.06
# AP@975_232 = 0.06
# AP@975_233 = 0.06
# AP@975_234 = 0.05
# AP@975_235 = 0.07
# AP@975_236 = 0.02
# AP@975_237 = 0.06
# AP@975_238 = 0.1
# AP@975_239 = 0.06
# AP@975_240 = 0.06
# AP@975_241 = 0.0
# AP@975_242 = 0.0
# AP@975_243 = 0.0
# AP@975_244 = 0.0
# AP@975_245 = 0.0
# AP@975_246 = 0.0
# AP@975_247 = 0.0
# AP@975_248 = 0.0
# AP@975_249 = 0.0
# AP@975_250 = 0.0
# AP@975_251 = 0.01
# AP@975_252 = 0.01
# AP@975_253 = 0.01
# AP@975_254 = 0.01
# AP@975_255 = 0.01
# AP@975_256 = 0.01
# AP@975_257 = 0.01
# AP@975_258 = 0.01
# AP@975_259 = 0.0
# AP@975_260 = 0.01
# AP@975_261 = 0.65
# AP@975_262 = 0.64
# AP@975_263 = 0.22
# AP@975_264 = 0.69
# AP@975_265 = 0.72
# AP@975_266 = 0.79
# AP@975_267 = 0.21
# AP@975_268 = 0.61
# AP@975_269 = 0.65
# AP@975_270 = 0.68
# AP@975_271 = 0.28
# AP@975_272 = 0.49
# AP@975_273 = 0.51
# AP@975_274 = 0.38
# AP@975_275 = 0.49
# AP@975_276 = 0.5
# AP@975_277 = 0.5
# AP@975_278 = 0.37
# AP@975_279 = 0.48
# AP@975_280 = 0.27
# AP@975_281 = 0.4
# AP@975_282 = 0.4
# AP@975_283 = 0.41
# AP@975_284 = 0.39
# AP@975_285 = 0.4
# AP@975_286 = 0.42
# AP@975_287 = 0.39
# AP@975_288 = 0.4
# AP@975_289 = 0.41
# AP@975_290 = 0.37
# AP@975_291 = 0.72
# AP@975_292 = 0.83
# AP@975_293 = 0.77
# AP@975_294 = 0.83
# AP@975_295 = 0.72
# AP@975_296 = 0.36
# AP@975_297 = 0.83
# AP@975_298 = 0.83
# AP@975_299 = 0.36
# AP@975_300 = 0.83
# AP@975_301 = 0.51
# AP@975_302 = 0.33
# AP@975_303 = 0.46
# AP@975_304 = 0.33
# AP@975_305 = 0.44
# AP@975_306 = 0.46
# AP@975_307 = 0.52
# AP@975_308 = 0.51
# AP@975_309 = 0.5
# AP@975_310 = 0.4
# AP@975_311 = 0.59
# AP@975_312 = 0.5
# AP@975_313 = 0.62
# AP@975_314 = 0.62
# AP@975_315 = 0.61
# AP@975_316 = 0.4
# AP@975_317 = 0.62
# AP@975_318 = 0.62
# AP@975_319 = 0.63
# AP@975_320 = 0.62
# AP@975_321 = 0.21
# AP@975_322 = 0.21
# AP@975_323 = 0.24
# AP@975_324 = 0.16
# AP@975_325 = 0.2
# AP@975_326 = 0.22
# AP@975_327 = 0.21
# AP@975_328 = 0.22
# AP@975_329 = 0.19
# AP@975_330 = 0.17
# AP@975_331 = 0.37
# AP@975_332 = 0.37
# AP@975_333 = 0.37
# AP@975_334 = 0.37
# AP@975_335 = 0.37
# AP@975_336 = 0.37
# AP@975_337 = 0.37
# AP@975_338 = 0.37
# AP@975_339 = 0.37
# AP@975_340 = 0.32
# AP@975_341 = 0.08
# AP@975_342 = 0.06
# AP@975_343 = 0.07
# AP@975_344 = 0.09
# AP@975_345 = 0.1
# AP@975_346 = 0.1
# AP@975_347 = 0.08
# AP@975_348 = 0.08
# AP@975_349 = 0.09
# AP@975_350 = 0.06
# AP@975_351 = 0.54
# AP@975_352 = 0.57
# AP@975_353 = 0.39
# AP@975_354 = 0.54
# AP@975_355 = 0.36
# AP@975_356 = 0.58
# AP@975_357 = 0.56
# AP@975_358 = 0.31
# AP@975_359 = 0.31
# AP@975_360 = 0.57
# mAP@975 = 0.2566
# 0.2565543807472802

# %%
def calculate_precision(test_Y, pred_all, k):

    Q = len(test_Y)
    precision_at_k_list = []

    pred = [i[0:k] for i in pred_all]

    # loop through and calculate AP for each query q
    for q in range(Q):
        ap_num = 0
        # loop through k values
        for x in range(len(pred[q])):
            # calculate precision@k
            act_set = set(test_Y[q])                                                                                                                                   
            pred_set = set(pred[q][:x+1])
            precision_at_k = len(act_set & pred_set) / (x+1)

        precision_at_k_list.append(precision_at_k)

    # now we take the mean of all ap values to get mAP
    pred_at_k = sum(precision_at_k_list) / Q

    # generate results
    print(f"Precision@{len(pred[q])} = {round(pred_at_k, 4)}")

    return pred_at_k

calculate_precision(test_Y, pred_all, 5)
# Out:
# Precision@5 = 0.2083
# 0.20833333333333345
